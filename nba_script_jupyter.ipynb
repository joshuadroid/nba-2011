# %%
import pandas as pd
path = "2010-11_pbp.csv"

# %%
import_csv = pd.read_csv(path, encoding="utf-8")

# %%
import_csv.describe()
# Out:
#           Unnamed: 0  EVENTMSGACTIONTYPE   EVENTMSGTYPE       EVENTNUM  \
# count  550989.000000       550989.000000  550989.000000  550989.000000
# mean      224.749944            8.202997       3.984700     264.525217
# std       131.579206           17.786903       2.646055     157.718663
# min         0.000000            0.000000       1.000000       0.000000
# 25%       111.000000            0.000000       2.000000     129.000000
# 50%       223.000000            1.000000       4.000000     262.000000
# 75%       335.000000            5.000000       5.000000     396.000000
# max       652.000000           96.000000      18.000000     783.000000
#
#             GAME_ID  NEUTRALDESCRIPTION         PERIOD    PERSON1TYPE  \
# count  5.509890e+05                 0.0  550989.000000  549654.000000
# mean   2.100061e+07                 NaN       2.548434       4.268420
# std    3.558852e+02                 NaN       1.141116       0.938356
# ...

# %%
import_csv["GAME_ID"].unique()
# Out:
# array([21000492, 21000854, 21001094, ..., 21000097, 21000972, 21001044],
#       dtype=int64)

# %%
columns = ["GAME_ID", "PLAYER1_TEAM_ABBREVIATION"]
games_and_teams_df = import_csv[columns]
games_and_teams_df.head()
# Out:
#     GAME_ID PLAYER1_TEAM_ABBREVIATION
# 0  21000492                       NaN
# 1  21000492                       NYK
# 2  21000492                       IND
# 3  21000492                       NaN
# 4  21000492                       IND

# %%
for x in range(5):
